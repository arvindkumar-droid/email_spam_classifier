# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('spam.csv',encoding='latin-1')

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# # Steps
# ### data cleaning
# ### EDA
# ### text preprocessing
# ### model building
# ### model evaluation
# ### improvement
# ### website
# ### Deploye

# %% [markdown]
# # 1.Data cleaning

# %%
df.info()
# last three column has nothing(very less values) so we will drop them.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns = ['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# renaming the columns because they are not that descriptive 
df.rename(columns = {'v1':'target','v2':'text'},inplace = True)
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
# we want the target column as number that's why we are doing label encoding
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])
# ham --- 0, spam ---- 1

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
# there are 403 duplicate values so we will drop them
df = df.drop_duplicates(keep = 'first')

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct = "%0.2f")
plt.show()

# %%
# by seeing the pie chart the Data is imbalanced

# %%
# !pip install nltk

# %%
import nltk

#The purpose of the NLTK (Natural Language Toolkit) library is to provide tools, resources, 
#and interfaces for working with human language (natural language) in Python. 
#It is widely used in Natural Language Processing (NLP) tasks such as text analysis, preprocessing, and linguistic data manipulation.

# %%
df['num_characters'] = df['text'].apply(len)
# total number of character in the message

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df['text'].apply(lambda x: nltk.word_tokenize(x))
# Out:
# 0       [Go, until, jurong, point, ,, crazy, .., Avail...
# 1                [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2       [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3       [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4       [Nah, I, do, n't, think, he, goes, to, usf, ,,...
#                               ...
# 5567    [This, is, the, 2nd, time, we, have, tried, 2,...
# 5568     [Will, Ì_, b, going, to, esplanade, fr, home, ?]
# 5569    [Pity, ,, *, was, in, mood, for, that, ., So, ...
# 5570    [The, guy, did, some, bitching, but, I, acted,...
# 5571                  [Rofl, ., Its, true, to, its, name]
# Name: text, Length: 5169, dtype: object

# %%
# num of words in a sms
df['num_word'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
# word_tokenize --- it break the sentence word by word

# %%
from nltk.tokenize import word_tokenize
word_tokenize("This is an example sentence.")
# Out:
# ['This', 'is', 'an', 'example', 'sentence', '.']

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\arvin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_word
# 0        24
# 1         8
# 2        37
# 3        13
# 4        15

# %%
df['text'].apply(lambda x:nltk.sent_tokenize(x))
# nltk.sent_tokenize() is used to split a piece of text into sentences.
# Out:
# 0       [Go until jurong point, crazy.., Available onl...
# 1                        [Ok lar..., Joking wif u oni...]
# 2       [Free entry in 2 a wkly comp to win FA Cup fin...
# 3       [U dun say so early hor... U c already then sa...
# 4       [Nah I don't think he goes to usf, he lives ar...
#                               ...
# 5567    [This is the 2nd time we have tried 2 contact ...
# 5568              [Will Ì_ b going to esplanade fr home?]
# 5569    [Pity, * was in mood for that., So...any other...
# 5570    [The guy did some bitching but I acted like i'...
# 5571                        [Rofl., Its true to its name]
# Name: text, Length: 5169, dtype: object

# %%
df['num_sentences'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_word  num_sentences
# 0        24              2
# 1         8              2
# 2        37              2
# 3        13              1
# 4        15              1

# %%
df.shape
# Out:
# (5169, 5)

# %%
df.describe()
# Out:
#             target  num_characters     num_word  num_sentences
# count  5169.000000     5169.000000  5169.000000    5169.000000
# mean      0.126330       78.977945    18.455794       1.965564
# std       0.332253       58.236293    13.324758       1.448541
# min       0.000000        2.000000     1.000000       1.000000
# 25%       0.000000       36.000000     9.000000       1.000000
# 50%       0.000000       60.000000    15.000000       1.000000
# 75%       0.000000      117.000000    26.000000       2.000000
# max       1.000000      910.000000   220.000000      38.000000

# %%
df[df['target'] == 0][['num_characters','num_word','num_sentences']].describe()
# for ham messeges
# Out:
#        num_characters     num_word  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
df[df['target'] == 1][['num_characters','num_word','num_sentences']].describe()
# for spam messeges
# Out:
#        num_characters    num_word  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %% [markdown]
# ### by seeing the hist plot it clearly seeing that average spam messeges have  more num_charater

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_word'])
sns.histplot(df[df['target'] == 1]['num_word'],color='red')
# Out:
# <Axes: xlabel='num_word', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
df.iloc[:,[0,2,3,4]].corr()
# Out:
#                   target  num_characters  num_word  num_sentences
# target          1.000000        0.384717  0.262912       0.263939
# num_characters  0.384717        1.000000  0.965760       0.624139
# num_word        0.262912        0.965760  1.000000       0.679971
# num_sentences   0.263939        0.624139  0.679971       1.000000

# %%
sns.heatmap(df.iloc[:,[0,2,3,4]].corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # 3. Data Preprocessing
# Lower case
#
# Tokenization
#
# Removing special characters
#
# Removing stop words and punctuation
#
# Stemming

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\arvin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words('english')

#What are Stopwords?

#Stopwords are common words in a language that usually carry very little meaningful information in the context of tasks like text classification, 
#sentiment analysis, or document clustering.
#Why Remove Stopwords?

#✅ They don’t contribute to the meaning of the text significantly

#✅ Helps in reducing the size of data for faster computation

#✅ Improves performance of ML models by focusing on important words
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))


    return " ".join(y)
    

# isalnum() -- only provide alpha numeric value
# text = y[:] -- cloning

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
df['text'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %% [markdown]
# # Stemming--
# ### What is Stemming?
#
# ####Stemming is the process of reducing a word to its base or root form by removing suffixes (and sometimes prefixes).
#
# ## Why Use Stemming?
#
# ####To treat different forms of the same word as the same feature during analysis.
#
# ####Example:
#
# #Original Words	 ___  After Stemming
# #running	__________            run
# #runner	 ____________               run
# #runs	____________                run

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('gazing')
# Out:
# 'gaze'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_word  num_sentences                                   transformed_text
# 0        24              2  go jurong point crazi avail bugi n great world...
# 1         8              2                              ok lar joke wif u oni
# 2        37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3        13              1                u dun say earli hor u c alreadi say
# 4        15              1               nah think goe usf live around though

# %% [markdown]
# # What is a Word Cloud?
#
# 👉 A Word Cloud is a visual representation of text data where:
#
# Each word’s size is proportional to its frequency or importance in the given text.
#
# More frequent words appear larger and bolder.
#
# Less frequent words appear smaller.
#
# # Purpose of Word Cloud
#
# To visually summarize large text data.
#
# Quickly see which words are most prominent.
#
# Useful for:
#
# Exploratory Data Analysis (EDA) in NLP
#
# Visualizing customer reviews, tweets, articles, etc.

# %%
from wordcloud import WordCloud
wc = WordCloud(width = 600,height = 600,min_font_size = 10,background_color = 'white' )

# %%
# this is for Spam messeges
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep = " "))

# %%
plt.figure(figsize = (14,8))
plt.imshow(spam_wc)

# %%
# this is for ham messeges
spam_wc1 = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep = " "))

# %%
plt.figure(figsize = (14,8))
plt.imshow(spam_wc1)

# %%
# we can see our top words 
x = df[df['target'] == 1]['transformed_text'].tolist()

# %%
spam_corpus = []
for msg in x:
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter

#What is Counter?

#Counter is a Python class from the collections module that helps count occurrences of elements in an iterable (like words in a list).
#Why Is Counter Useful in NLP?

#Counting word frequencies in a corpus

#Building term frequency dictionaries

#Simple and fast way to analyze word distributions

# %%
Counter(spam_corpus)
# Out:
# Counter({'call': 320,
#          'free': 191,
#          '2': 155,
#          'txt': 141,
#          'text': 122,
#          'u': 119,
#          'ur': 119,
#          'mobil': 114,
#          'stop': 104,
#          'repli': 103,
#          'claim': 98,
#          '4': 97,
#          'prize': 82,
#          'get': 74,
#          'new': 64,
#          'servic': 64,
#          'tone': 63,
#          'send': 60,
#          'urgent': 57,
#          'nokia': 57,
#          'contact': 56,
#          'award': 55,
#          'phone': 52,
#          'cash': 51,
#          'pleas': 51,
#          'week': 49,
#          'win': 48,
#          'c': 45,
#          'collect': 45,
#          'min': 45,
#          'custom': 42,
#          'messag': 42,
#          'guarante': 42,
#          'per': 41,
#          'chat': 38,
#          'tri': 37,
#          'msg': 35,
#          'draw': 35,
#          'number': 35,
#          'cs': 35,
#          'show': 33,
#          'today': 33,
# ...

# %%
Counter(spam_corpus).most_common(30)
# Out:
# [('call', 320),
#  ('free', 191),
#  ('2', 155),
#  ('txt', 141),
#  ('text', 122),
#  ('u', 119),
#  ('ur', 119),
#  ('mobil', 114),
#  ('stop', 104),
#  ('repli', 103),
#  ('claim', 98),
#  ('4', 97),
#  ('prize', 82),
#  ('get', 74),
#  ('new', 64),
#  ('servic', 64),
#  ('tone', 63),
#  ('send', 60),
#  ('urgent', 57),
#  ('nokia', 57),
#  ('contact', 56),
#  ('award', 55),
#  ('phone', 52),
#  ('cash', 51),
#  ('pleas', 51),
#  ('week', 49),
#  ('win', 48),
#  ('c', 45),
#  ('collect', 45),
#  ('min', 45)]

# %%
df_freq = pd.DataFrame(Counter(spam_corpus).most_common(30), columns=['word', 'count']) 
# let's store it in a data frame
# pd.DataFrame(Counter(spam_corpus).most_common(30))
## now plot a bar plot
sns.barplot(x='count', y='word', data=df_freq)
# Out:
# <Axes: xlabel='count', ylabel='word'>

# %%
# similarly for the ham messeges
z = df[df['target'] == 0]['transformed_text'].tolist()

# %%
ham_corpus = []
for msg in z:
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
Counter(ham_corpus).most_common(30)
# Out:
# [('u', 883),
#  ('go', 404),
#  ('get', 349),
#  ('gt', 288),
#  ('lt', 287),
#  ('2', 284),
#  ('come', 275),
#  ('got', 236),
#  ('know', 236),
#  ('like', 234),
#  ('call', 233),
#  ('time', 219),
#  ('ok', 217),
#  ('love', 216),
#  ('good', 213),
#  ('want', 208),
#  ('ur', 197),
#  ('day', 190),
#  ('need', 170),
#  ('one', 165),
#  ('lor', 159),
#  ('4', 156),
#  ('home', 152),
#  ('think', 149),
#  ('see', 147),
#  ('take', 143),
#  ('still', 143),
#  ('da', 142),
#  ('tell', 133),
#  ('make', 129)]

# %%
df_freq1 = pd.DataFrame(Counter(ham_corpus).most_common(30), columns=['word', 'count']) 
# let's store it in a data frame
# pd.DataFrame(Counter(spam_corpus).most_common(30))
## now plot a bar plot
sns.barplot(x='count', y='word', data=df_freq1)
# Out:
# <Axes: xlabel='count', ylabel='word'>

# %% [markdown]
# # Model Building

# %% [markdown]
# The best model for textual data depends on your specific task (e.g., classification, sentiment analysis, generation) and dataset size, but here’s a clear, well-organized summary of top-performing models for common NLP tasks:

# %% [markdown]
# # Traditional Machine Learning Models (Good for Small to Medium Datasets)
#
# ## Logistic Regression
#
# Description: Simple and effective for text classification
#
# Pros: Fast, interpretable
#
# Cons: Limited for complex patterns
#
# ## Naive Bayes (MultinomialNB)
#
# Description: Works well for text classification (e.g., spam detection, sentiment analysis)
#
# Pros: Simple, performs well on word counts
#
# Cons: Assumes feature independence
#
# ## Support Vector Machine (SVM)
#
# Description: Powerful for high-dimensional text data
#
# Pros: Good accuracy with proper kernels
#
# Cons: Computationally expensive for large datasets
#
# ## Random Forest
#
# Description: Ensemble model, handles non-linearities
#
# Pros: Robust, handles noisy data
#
# Cons: Less interpretable

# %%
# for these model you have to provide numerical input
# if input is in the text form convert them into vector form
#3️⃣ Support Vector Machine (SVM)

# Expected Input:

#X: Feature matrix (n_samples, n_features)

#y: Target labels

# In text tasks:

#Usually use TF-IDF Vectorizer for better performance in high-dimensional data.

# Bag of Words (BoW)
# CountVectorizer

# Concept:

# Counts the frequency of each word in the document.

# Ignores grammar and word order.

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
#cv = CountVectorizer()
tfidf = TfidfVectorizer()

# %% [markdown]
# CountVectorizer
#
# Converts a collection of text documents into a matrix of word counts.
#
# Each word becomes a feature (column).
#
# Each document becomes a vector of counts (rows).

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %% [markdown]
# cv.fit_transform(df['transformed_text'])
#
# Applies CountVectorizer to the text column:
#
# Learns the vocabulary (all unique words in the corpus).
#
# Transforms each document into a vector of word counts.
#
# Output:
#
# A sparse matrix of shape (n_samples, n_features).

# %%
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#X = scaler.fit_transform(X)

# %%
X.shape
# Out:
# (5169, 6708)

# %%
y = df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 2)

# %% [markdown]
# #### When i did vectorization with tfidf then precision of mnb medel increased and that's what we want

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8723404255319149
# [[782 114]
#  [ 18 120]]
# 0.5128205128205128

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9787234042553191
# [[889   7]
#  [ 15 123]]
# 0.9461538461538461

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %% [markdown]
# 1️⃣ Precision
#
# 👉 Definition:
#
# Of all predicted positive (e.g., spam), how many are actually positive?
#
# Formula:
# Precision=TP/(FP+TP)
#
#
# 🔸 Why It Matters:
#
# You don’t want to classify a normal message as spam (False Positive).
#
# High Precision → Less false alarms.
#
# 3️⃣ F1-Score
# F1=2×(Precision*Recall)/(Precision+Recall)
# 👉 Definition:
#
# Harmonic mean of Precision and Recall.
#
# Formula:
#
# 🔸 Why It Matters:
#
# Balances Precision and Recall → Ideal for imbalanced data.

# %% [markdown]
# # till now we have choosed tfidf and mnb

# %%
# we will check accuracy and and precision for different algorithm.
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.ensemble import GradientBoostingClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt
    
}

# %%
def train_classifier(clf,X_train,X_test,y_train,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)


    return accuracy, precision

# %%
train_classifier(svc,X_train,X_test,y_train,y_test)
# Out:
# (0.9690522243713733, 0.9274193548387096)

# %%
train_classifier(rfc,X_train,X_test,y_train,y_test)
# Out:
# (0.9758220502901354, 0.9829059829059829)

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    current_accuracy,current_precision = train_classifier(clf,X_train,X_test,y_train,y_test)
    print('for ',name)
    print('Accuracy',current_accuracy)
    print('Precision',current_precision)
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# for  SVC
# Accuracy 0.9690522243713733
# Precision 0.9274193548387096
# for  KN
# Accuracy 0.9052224371373307
# Precision 0.9761904761904762
# for  NB
# Accuracy 0.9787234042553191
# Precision 0.9461538461538461
# for  DT
# Accuracy 0.9274661508704062
# Precision 0.8118811881188119
# for  LR
# Accuracy 0.9671179883945842
# Precision 0.9642857142857143
# for  RF
# Accuracy 0.9758220502901354
# Precision 0.9829059829059829
# C:\Users\arvin\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# for  AdaBoost
# Accuracy 0.960348162475822
# Precision 0.9292035398230089
# for  BgC
# Accuracy 0.9584139264990329
# Precision 0.8682170542635659
# for  ETC
# Accuracy 0.9748549323017408
# Precision 0.9745762711864406
# for  GBDT
# Accuracy 0.9468085106382979
# Precision 0.9191919191919192

# %% [markdown]
# # so till now we have choosen the tfidf = TfidfVectorizer() vectorization technique and some good results are produced by some model

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#   Algorithm  Accuracy  Precision
# 1        KN  0.900387   1.000000
# 2        NB  0.959381   1.000000
# 5        RF  0.971954   1.000000
# 8       ETC  0.972921   0.982456
# 0       SVC  0.972921   0.974138
# 6  AdaBoost  0.961315   0.945455
# 4        LR  0.951644   0.940000
# 9      GBDT  0.952611   0.923810
# 7       BgC  0.958414   0.862595
# 3        DT  0.937137   0.854369

# %% [markdown]
# # let's emprove our model by hyperparameter tunning
# ### by doing this (tfidf = TfidfVectorizer(max_features=3000))
#
# #### What is TfidfVectorizer?
#
# #### It converts a collection of text documents into a matrix of TF-IDF features.
#
# #### TF-IDF stands for:
#
# #### Term Frequency – How frequently a word appears in a document.
#
# #### Inverse Document Frequency – How rare the word is across all documents.
#
# #### What does max_features=3000 do?
#
# #### Limits the number of features (i.e., unique words or tokens) in the final matrix to the top 3000 most important words (based on frequency and TF-IDF score).

# %%
# So again i am running the whole code by changing the max_features=3000

# %%
# improved model
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)

# %%
temp_df
# Out:
#   Algorithm  Accuracy_max_ft_3000  Precision_max_ft_3000
# 1        KN              0.905222               1.000000
# 2        NB              0.970986               1.000000
# 5        RF              0.975822               0.982906
# 0       SVC              0.975822               0.974790
# 8       ETC              0.974855               0.974576
# 4        LR              0.958414               0.970297
# 6  AdaBoost              0.960348               0.929204
# 9      GBDT              0.946809               0.919192
# 7       BgC              0.958414               0.868217
# 3        DT              0.932302               0.833333

# %%
new_df = performance_df.merge(temp_df,on='Algorithm')

# %%
new_df_scaled = new_df.merge(temp_df,on='Algorithm')

# %%
new_df_scaled
# Out:
#   Algorithm  Accuracy  Precision  Accuracy_max_ft_3000_x  \
# 0        KN  0.900387   1.000000                0.905222
# 1        NB  0.959381   1.000000                0.970986
# 2        RF  0.971954   1.000000                0.975822
# 3       ETC  0.972921   0.982456                0.974855
# 4       SVC  0.972921   0.974138                0.975822
# 5  AdaBoost  0.961315   0.945455                0.960348
# 6        LR  0.951644   0.940000                0.958414
# 7      GBDT  0.952611   0.923810                0.946809
# 8       BgC  0.958414   0.862595                0.958414
# 9        DT  0.937137   0.854369                0.932302
#
#    Precision_max_ft_3000_x  Accuracy_max_ft_3000_y  Precision_max_ft_3000_y
# 0                 1.000000                0.905222                 1.000000
# 1                 1.000000                0.970986                 1.000000
# 2                 0.982906                0.975822                 0.982906
# ...

# %%
# Voting Classifier
svc = SVC(kernel='sigmoid', gamma=1.0,probability=True)
mnb = MultinomialNB()
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)

from sklearn.ensemble import VotingClassifier

# %%
voting = VotingClassifier(estimators=[('svm', svc), ('nb', mnb), ('et', etc)],voting='soft')
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9796905222437138
# Precision 0.968

# %%
rfc = RandomForestClassifier(
    n_estimators=200,        # More trees for better performance
    max_depth=20,            # Limits tree depth
    min_samples_split=5,
    min_samples_leaf=2,
    max_features='sqrt',     # Common choice
    n_jobs=-1,               # Parallel training
    random_state=42
)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=200, n_jobs=-1, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=42, n_jobs=-1),
                           param_grid, cv=5, scoring='accuracy')

grid_search.fit(X_train, y_train)
best_rf = grid_search.best_estimator_

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              param_grid={'max_depth': [10, 20, None],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='accuracy')

# %%
param_grid
# Out:
# {'n_estimators': [100, 200],
#  'max_depth': [10, 20, None],
#  'min_samples_split': [2, 5]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# Define parameter grid
param_grid = {
    'n_estimators': [50,100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
}

# Set up GridSearchCV with multiple scoring metrics
grid_search = GridSearchCV(
    RandomForestClassifier(random_state=42, n_jobs=-1),
    param_grid,
    scoring=['accuracy', 'precision'],
    refit='accuracy',     # Select which metric to optimize for final model
    cv=5,
    return_train_score=True
)

# Fit the grid search
grid_search.fit(X_train, y_train)

# Best model based on accuracy
best_model = grid_search.best_estimator_

# Print best scores
print("Best Accuracy:", grid_search.best_score_)
print("Best Parameters:", grid_search.best_params_)

# Evaluate precision separately
from sklearn.metrics import precision_score, accuracy_score

y_pred = best_model.predict(X_test)

print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Test Precision:", precision_score(y_test, y_pred))
# Out:
# Best Accuracy: 0.9697702539298672
# Best Parameters: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 50}
# Test Accuracy: 0.9748549323017408
# Test Precision: 1.0

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
rfc = RandomForestClassifier(n_estimators=50,min_samples_split = 5, random_state=2)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(min_samples_split=5, n_estimators=50, random_state=2)

# %%
rfc.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(accuracy_score(y_test, y_pred))
print(precision_score(y_test, y_pred))
# Out:
# 0.9748549323017408
# 1.0

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(rfc,open('model.pkl','wb'))
